# %%
# Import Dependencies
import pandas as pd

# %%
# Load in the data
raw_data = pd.read_csv('Resources/Texas_EVs.csv')

# View data
raw_data.head()
# Out:
# /var/folders/fg/v0nvddp96gq_9d0n5y5m60840000gn/T/ipykernel_57790/2700959308.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv('Resources/Texas_EVs.csv')
#   State ZIP Code Registration Date Vehicle Make Vehicle Model  \
# 0    TX    78617         10/1/2022        TESLA       MODEL 3
# 1    TX    76247         10/1/2022        TESLA       MODEL 3
# 2    TX    79407         10/1/2022        TESLA       MODEL 3
# 3    TX    78611         10/1/2022        TESLA       MODEL 3
# 4    TX    77303         10/1/2022        TESLA       MODEL 3
#
#    Vehicle Model Year Drivetrain Type Vehicle GVWR Class  \
# 0                2018             BEV                  1
# 1                2018             BEV                  1
# 2                2018             BEV                  1
# 3                2018             BEV                  1
# 4                2018             BEV                  1
#
# ...

# %%
# Add column msrp
raw_data.loc[raw_data['Vehicle Model'] == 'MODEL 3', 'Base_MSRP'] = 40240
raw_data.loc[raw_data['Vehicle Model'] == 'MODEL S', 'Base_MSRP'] = 78490
raw_data.loc[raw_data['Vehicle Model'] == 'MODEL Y', 'Base_MSRP'] = 47740
raw_data.loc[raw_data['Vehicle Model'] == 'MODEL X', 'Base_MSRP'] = 88490
raw_data.loc[raw_data['Vehicle Model'] == 'LEAF', 'Base_MSRP'] = 29985
raw_data.loc[raw_data['Vehicle Model'] == 'BOLT', 'Base_MSRP'] = 40240
raw_data.loc[raw_data['Vehicle Model'] == 'MUSTANG MACH-E', 'Base_MSRP'] = 42995
raw_data.loc[raw_data['Vehicle Model'] == 'E-TRON', 'Base_MSRP'] = 74400
raw_data.loc[raw_data['Vehicle Model'] == 'TAYCAN', 'Base_MSRP'] = 86700
raw_data.loc[raw_data['Vehicle Model'] == 'ID.4', 'Base_MSRP'] = 38995
raw_data.loc[raw_data['Vehicle Model'] == 'I3', 'Base_MSRP'] = 44450
raw_data.loc[raw_data['Vehicle Model'] == '500', 'Base_MSRP'] = 29505

#View data
raw_data.head()
# Out:
#   State ZIP Code Registration Date Vehicle Make Vehicle Model  \
# 0    TX    78617         10/1/2022        TESLA       MODEL 3
# 1    TX    76247         10/1/2022        TESLA       MODEL 3
# 2    TX    79407         10/1/2022        TESLA       MODEL 3
# 3    TX    78611         10/1/2022        TESLA       MODEL 3
# 4    TX    77303         10/1/2022        TESLA       MODEL 3
#
#    Vehicle Model Year Drivetrain Type Vehicle GVWR Class  \
# 0                2018             BEV                  1
# 1                2018             BEV                  1
# 2                2018             BEV                  1
# 3                2018             BEV                  1
# 4                2018             BEV                  1
#
#           Vehicle Category  Vehicle Count  DMV Snapshot ID  \
# 0  Light-Duty (Class 1-2A)              1                5
# 1  Light-Duty (Class 1-2A)              1                5
# 2  Light-Duty (Class 1-2A)              1                5
# ...
